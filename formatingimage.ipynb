# %% [markdown]
# <a href="https://colab.research.google.com/github/Afrizal2609/Dataset/blob/main/formatingimage.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

# Get the current working directory
cwd = os.getcwd()

# Print the current working directory
print("Current working directory: {0}".format(cwd))

# Print the type of the returned object
print("os.getcwd() returns an object of type: {0}".format(type(cwd)))
# Out:
# Current working directory: /content
# os.getcwd() returns an object of type: <class 'str'>

# %%
import zipfile
with zipfile.ZipFile('/content/photos.zip', 'r') as zip_ref:
    zip_ref.extractall('/content')

# %%
os.mkdir('/content/formatedphotos')

# %%
import PIL
import os.path
from PIL import Image, ImageFile

ImageFile.LOAD_TRUNCATED_IMAGES = True

f = r'/content/photos/'
for folder in os.listdir(f):
  os.mkdir('/content/formatedphotos/'+folder)
  print(folder)
  for file in os.listdir(f+folder):
    print(file)
    try:
      f_img = f+folder+'/'+file
      img = Image.open(f_img)
      img = img.convert("RGB")
      img = img.resize((300,300))
      if file.endswith(".jpeg") or file.endswith(".webp"): 
        file_name, file_ext = os.path.splitext(file)
      img.save('/content/formatedphotos/'+folder+'/{}.png'.format(file_name))
    except:
      pass
# Out:
# Sendok Plastik
# PlasticSpoon42.png
# PlasticSpoon564.png
# PlasticSpoon793.png
# PlasticSpoon722.jpeg
# PlasticSpoon261.png
# PlasticSpoon516.png
# PlasticSpoon312.png
# PlasticSpoon728.png
# PlasticSpoon559.jpeg
# PlasticSpoon602.png
# PlasticSpoon371.jpeg
# PlasticSpoon742.png
# PlasticSpoon100.jpeg
# PlasticSpoon209.jpeg
# PlasticSpoon373.png
# PlasticSpoon642.jpeg
# PlasticSpoon554.png
# PlasticSpoon91.png
# PlasticSpoon144.jpeg
# PlasticSpoon351.png
# PlasticSpoon84.jpeg
# PlasticSpoon78.png
# PlasticSpoon380.png
# PlasticSpoon104.jpeg
# PlasticSpoon131.png
# PlasticSpoon134.jpeg
# PlasticSpoon284.jpeg
# PlasticSpoon837.png
# PlasticSpoon94.png
# PlasticSpoon426.jpeg
# PlasticSpoon473.png
# PlasticSpoon687.png
# PlasticSpoon573.png
# PlasticSpoon193.png
# PlasticSpoon827.png
# PlasticSpoon168.png
# PlasticSpoon3.png
# PlasticSpoon274.png
# PlasticSpoon34.jpeg
# PlasticSpoon276.webp
# PlasticSpoon217.jpeg
# PlasticSpoon768.jpeg
# PlasticSpoon739.jpeg
# PlasticSpoon107.png
# ...
